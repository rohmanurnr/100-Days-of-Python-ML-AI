# %%
import pandas as pd
import numpy as np

np.random.seed(42)
data = {
    'Fitur 1': np.random.normal(0, 1, 100),
    'Fitur 2': np.random.normal(1, 1, 100),
    'Kelas': [0] * 90 + [1] * 10 
}

df = pd.DataFrame(data)
print("Dataset Asli:")
print(df['Kelas'].value_counts())
# Out:
# Dataset Asli:
# Kelas
# 0    90
# 1    10
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df['Kelas'].value_counts().plot(kind='bar', color=['blue', 'orange'])
plt.title('Distribusi Kelas')
plt.xlabel('Kelas')
plt.ylabel('Jumlah Data')
plt.savefig('18_01.png', format='png', dpi=300)
plt.show()

# %%
pip install imblearn
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.12.4-py3-none-any.whl (258 kB)
#      ---------------------------------------- 0.0/258.3 kB ? eta -:--:--
#      - -------------------------------------- 10.2/258.3 kB ? eta -:--:--
#      -- ---------------------------------- 20.5/258.3 kB 217.9 kB/s eta 0:00:02
#      -------- ---------------------------- 61.4/258.3 kB 465.5 kB/s eta 0:00:01
#      ------------------------------ ------- 204.8/258.3 kB 1.2 MB/s eta 0:00:01
#      -------------------------------------- 258.3/258.3 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.5.0 in c:\users\hp\miniconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\hp\miniconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.5.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\hp\miniconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hp\miniconda3\lib\site-packages (from imbalanced-learn->imblearn) (3.5.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\hp\miniconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.4.2)
# Installing collected packages: imbalanced-learn, imblearn
# Successfully installed imbalanced-learn-0.12.4 imblearn-0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

X = df[['Fitur 1', 'Fitur 2']]
y = df['Kelas']

smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

df_resampled = pd.DataFrame(X_resampled, columns=['Fitur 1', 'Fitur 2'])
df_resampled['Kelas'] = y_resampled

print("\nDataset Setelah Oversampling:")
print(df_resampled['Kelas'].value_counts())
# Out:
# Dataset Setelah Oversampling:
# Kelas
# 0    90
# 1    90
# Name: count, dtype: int64

# %%
df_resampled['Kelas'].value_counts().plot(kind='bar', color=['blue', 'orange'])
plt.title('Distribusi Kelas Setelah Oversampling')
plt.xlabel('Kelas')
plt.ylabel('Jumlah Data')
plt.savefig('18_02.png', format='png', dpi=300)
plt.show()
