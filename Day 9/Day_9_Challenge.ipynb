# %% [markdown]
# # Install Library Matplotlib

# %%
pip install seaborn matplotlib pandas
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#      - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#      -- ---------------------------------- 20.5/294.9 kB 165.2 kB/s eta 0:00:02
#      ------ ------------------------------ 51.2/294.9 kB 292.6 kB/s eta 0:00:01
#      ------------------ ----------------- 153.6/294.9 kB 766.6 kB/s eta 0:00:01
#      ------------------------------------ - 286.7/294.9 kB 1.2 MB/s eta 0:00:01
#      -------------------------------------- 294.9/294.9 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in c:\users\hp\miniconda3\lib\site-packages (3.9.3)
# Requirement already satisfied: pandas in c:\users\hp\miniconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\hp\miniconda3\lib\site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\miniconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\miniconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\miniconda3\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\hp\miniconda3\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\miniconda3\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\miniconda3\lib\site-packages (from matplotlib) (4.55.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\hp\miniconda3\lib\site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\miniconda3\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\miniconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\miniconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\miniconda3\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\hp\miniconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Import Library Matplotlib

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # Unggah Dataset Iris

# %%
df = pd.read_csv('iris.csv')  # Ganti dengan path file CSV Anda
print(df.head())
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# # Membuat heatmap untuk melihat korelasi antar data

# %%
numeric_df = df.select_dtypes(include=[np.number])
correlation_matrix = numeric_df.corr()

plt.figure(figsize=(8, 6)) 
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Heatmap Korelasi Antar Data") 
plt.savefig('heatmap_korelasi.png', format='png', dpi=500)
plt.show()

# %% [markdown]
# # Membuat pairplot untuk melihat hubungan antar variabel

# %%
sns.pairplot(df, hue="variety", palette="Set1") 
plt.title("Pairplot Hubungan Antar Variabel")
plt.savefig('pairplot.png', format='png', dpi=500)
plt.show()

# %% [markdown]
# # Menambahkan parameter untuk memperindah visualisasi

# %%
#### Pairplot dengan lebih banyak pengaturan estetika
sns.pairplot(df, hue="variety", palette="Set2", markers=["o", "s", "D"], plot_kws={'alpha': 0.7})
plt.suptitle("Pairplot yang Ditingkatkan", y=1.02)
plt.savefig('pairplot_tingkatan.png', format='png', dpi=500)
plt.show()
